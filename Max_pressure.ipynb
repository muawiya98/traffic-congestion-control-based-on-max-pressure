# %%
from keras.layers import Dense, Input ,LeakyReLU ,Activation, Flatten
from concurrent.futures import ProcessPoolExecutor
from concurrent.futures import ThreadPoolExecutor
from keras.models import load_model as __ldm
from keras.models import save_model as __sdm
from concurrent.futures import wait
from keras.models import Sequential
from abc import abstractmethod, ABC
from keras.optimizers import Adam
import matplotlib.pyplot as plt
from collections import deque
from datetime import datetime
from math import floor,ceil
from pandas import array
from cgitb import reset
from tqdm import tqdm
import pandas as pd
import numpy as np
import datetime
import random
import pickle
import math
import os
import math

# %%
rewards = [3,6,5]
def plot_reward(step=5, color="blue"):
    step=int(len(rewards)/2)
    plt.figure(figsize=(6, 4))
    plt.title('algorithm_name')
    plt.plot([i for i, x in enumerate(rewards) if i % step == 0],
             [x for i, x in enumerate(rewards) if i % step == 0], color=color)
    plt.xlabel('Episodes')
    plt.ylabel('Total Reward per Epidode')
    
#     plt.show()
plot_reward()

# %%
y_target[0][action] = reward + self.gamma * 0.5
# Out:
# 6
# 7

# %%
angle = -90
angle = 270 if angle == -90 else angle
angle
# Out:
# 270

# %%
def policy(state_idx,epsilon):
    rand = np.random.uniform(0, 1)
    if rand > epsilon:
        return np.argmax([0,1])
    else:
        return np.random.choice([0, 1])
for i in range(5):
    print(policy(np.array([1,2,5,7,1,3,5,6,98,74,1]),0.1**i))
# Out:
# 0
# 1
# 1
# 1
# 1

# %%
f = np.array([2,5,8,7,9,6,3,3,5,8,8,546,6,6,5,8,5])
g = [4,6,4]
d = 0
for i in g :
    print("=====",d,i,"=====")
    a = f[d:i+d]
    print(a)
    d = i
# Out:
# ===== 0 4 =====
# [2 5 8 7]
# ===== 4 6 =====
# [9 6 3 3 5 8]
# ===== 6 4 =====
# [3 3 5 8]

# %%
math.atan2(5,0)
# Out:
# 1.5707963267948966

# %%
a = np.array([12,1,2,3,5,84,4,1])[[1,7,2,3,6,4,0,5]].tolist()
a
# Out:
# [1, 1, 2, 3, 4, 5, 12, 84]

# %%
dic = {'d':{"q":2,"w":21},"1":{"t",23},"w":{"x":1}}
for i in dic:
    if "q" in dic[i].keys:
        print(dic[i]["q"])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-48c6c1474f56> in <module>
#       1 dic = {'d':{"q":2,"w":21},"1":{"t",23},"w":{"x":1}}
#       2 for i in dic:
# ----> 3     if "q" in [dic[i].keys]:
#       4         print(dic[i]["q"])
#
# AttributeError: 'set' object has no attribute 'keys'

# %%
s,d = [],[]
for i in range(10):
    s.append(i)
print(len(s))
print(len(d))
# Out:
# 10
# 0

# %%
# df = pd.DataFrame(columns=['timestamp','vehicle_id','X_vehicle_position','Y_vehicle_position','vehicle_speed',
#                            'vehicle_acceleration','traffic_light_state','front_vehicle_id',
#                            'lane_id','intersction_id','lanes_leading_1','lanes_leading_2','vehicle_length',
#                            'Gap','vehicle_arrangement','is_last','is_first','lane_length','number_of_vehical_on_lane',
#                            'number_of_places_available_in_lane','num_incoming_vehicle','angle_movment'])
# df[df.columns[0]] = np.array([1]*8) # timestamp
# df[df.columns[1]] = np.array(range(8)) # vehicle_id
# df[df.columns[2]] = np.array([8,6.5,5,9,11,11,12,13.5]) # X_vehicle_position
# df[df.columns[3]] = np.array([13,13,13,16,12,10.5,15,15]) # Y_vehicle_position
# df[df.columns[4]] = np.array([2.50,2.30,2.10,2.75,1.54,3.00,1.54,1.48]) # vehicle_speed
# df[df.columns[5]] = np.array([0.4,0.20,0.02,0.1,0.1,0.5,0.05,0.04]) # vehicle_acceleration
# df[df.columns[6]] = np.array([1,1,1,0,1,1,0,0]) # traffic_light_state
# df[df.columns[7]] = np.array([-1,0,1,-1,-1,4,-1,6]) # front_vehicle_id
# df[df.columns[8]] = np.array([0,0,0,1,2,2,3,3]) # lane_id
# df[df.columns[9]] = np.array([0]*8) # intersction_id
# df[df.columns[10]] = np.array([16,16,16,5,14,14,11,11]) # lanes_leading_1
# df[df.columns[11]] = np.array([18,18,18,4,15,15,9,9]) # lanes_leading_2
# df[df.columns[12]] = np.array([1]*8) # vehicle_length
# df[df.columns[13]] = np.array([0.5]*8) # Gap
# df[df.columns[14]] = np.array([1,2,3,1,1,2,1,2]) # vehicle_arrangement
# df[df.columns[15]] = np.array([False,False,True,True,False,True,False,True]) # is_last
# df[df.columns[16]] = np.array([True,False,False,True,True,False,True,False]) # is_first  lane_length
# df[df.columns[17]] = np.array([4,4,4,6,4,4,8,8]) # lane_length
# df[df.columns[18]] = np.array([3,3,3,1,2,2,2,2]) # number_of_vehical_on_lane
# df[df.columns[19]] = np.array([0,0,0,3,1,1,3,3]) # number_of_places_available_in_lane
# df[df.columns[20]] = np.array([2,2,2,1,1,1,3,3]) # num_incoming_vehicle_1
# df[df.columns[20]] = np.array([1,1,1,0,0,0,2,2]) # num_incoming_vehicle_2
# df[df.columns[21]] = np.array([0,0,0,270,90,90,180,180]) # angle_movment

# %%
# df.head(8)

# %%
# df.to_csv("one_time_step.csv",index=False) # one_time_step

# %%
df = pd.read_csv("C:\\Users\\user\\Python_Anaconda\\Tasks\\03_A Novel Reinforcement Learning-based Cooperative Traffic Signal System through Max-pressure Control\\congestion-control-2\\output.csv")
print(df.shape)
df = df.mask(df.eq(np.nan)).dropna()
print(df.shape)
df.head()
# Out:
# (0, 26)
# (0, 26)
# Empty DataFrame
# Columns: [timestamp, vehicle_id, X_vehicle_position, Y_vehicle_position, vehicle_speed, vehicle_acceleration, traffic_light_state, front_vehicle_id, lane_id, intersction_id, lanes_leading_1, lanes_leading_2, vehicle_length, Gap, vehicle_arrangement, lane_length, number_of_vehical_on_lane, number_of_places_available_in_lane, num_veh_neighbor_lane, avg_speed_veh_neighbor_lane, avg_acceleration_veh_neighbor_lane, angle_movment, number_of_vehicles_moving_from_1, number_of_vehicles_moving_from_2, start_lane, end_lane]
# Index: []
#
# [0 rows x 26 columns]

# %%
df.columns
# Out:
# Index(['timestamp', 'vehicle_id', 'X_vehicle_position', 'Y_vehicle_position',
#        'vehicle_speed', 'vehicle_acceleration', 'traffic_light_state',
#        'front_vehicle_id', 'lane_id', 'intersction_id', 'lanes_leading_1',
#        'lanes_leading_2', 'vehicle_length', 'Gap', 'vehicle_arrangement',
#        'lane_length', 'number_of_vehical_on_lane',
#        'number_of_places_available_in_lane', 'num_veh_neighbor_lane',
#        'avg_speed_veh_neighbor_lane', 'avg_acceleration_veh_neighbor_lane',
#        'angle_movment', 'number_of_vehicles_moving_from_1',
#        'number_of_vehicles_moving_from_2', 'start_lane', 'end_lane'],
#       dtype='object')

# %% [markdown]
# # reward :
# ###### we will design a reward model based on MP that measures the pressure of vehicular movements at an intersection based on incoming and outgoing queue length measurements.

# %%
def get_lanes_information_from_enviroment():
    pass

# %% [markdown]
# #### 1 _ the pressure of a vehicular movement from incoming lane l to outgoing lane m at time step t as follows:
# ![2.PNG](attachment:2.PNG)

# %%
def calculate_pressure_of_vehicular_movement(numberOfVehicles_l_m, C, trafficSignals,numberOfVehicles_k_l): # (2) 5
    """
    numberOfVehicles_l_m (qt(l, m)) : denotes the number of vehicles moving from lane l to lane m
    
    C (Ct(m)) : denotes the vacancy of exiting lane m that is available for incoming vehicles at time step t.
    
    trafficSignals (sj,t(k, l) =) : is a binary variable denoting the traffic signals of the vehicular movements 
                                    from lane k to lane l. value 1 means that the signal is green for the 
                                    vehicular movement (k, l) at time step t; otherwise, it returns 0.
    
    
    numberOfVehicles_k_l (qt(k, l)) : denotes the number of vehicles moving from lane k to lane l
    
    """
    T = 0 
    for i,trafficSignal in enumerate(trafficSignals):
        T += trafficSignal*numberOfVehicles_k_l[i]
    return numberOfVehicles - C + T

# %% [markdown]
# #### 2 _ Based on the pressure measurements described above, the pressure of intersection i at time step t is defined as
# ![3.PNG](attachment:3.PNG)

# %%
def pressure_on_intersection(LANES): # (3) 5
    pressureOfIntersection = 0
    for lane in LANES:
        pressureOfIntersection += calculate_pressure_of_vehicular_movement(lane[0],lane[1],lane[2],lane[3])
    return pressureOfIntersection

# %% [markdown]
# #### The objective of the traffic signal controller is to minimize the total pressure of the intersection. Therefore, we define the reward rt at time step t as follows:
# ![4.PNG](attachment:4.PNG)

# %%
def reward(LANES): # (4) 5
    return -pressure_on_intersection(LANES)

# %%
for inter_id in list(set(df["intersction_id"].tolist())):
    inter = df[df['intersction_id']==inter_id]
    lanes_id = list(set(inter['lane_id'].tolist()))
    # number_of_vehical_on_lane
    for lane in df:
        pass
    reward(LANES)

# %% [markdown]
# # Traffic State Measurement

# %% [markdown]
# #### 1 _ delay :
# #### the delay of the message MVi from vehicle Vi to the intersection can be calculated as follows
# ![5.PNG](attachment:5.PNG)

# %%
from datetime import datetime
def get_current_time(): # time prefcounter
    time = datetime.now()
    Hour =  time.hour*360
    Minute = time.minute*60
    Second = Hour+Minute+time.second
    #print(time.hour,time.minute,time.second)
    return Second

# %%
def get_delay(Time_sent): # (5) 6
    return get_current_time() - Time_sent

# %% [markdown]
# #### 2 _ distance :
# #### the expected moving distance of Vi can be estimated as follows :
# ![6.PNG](attachment:6.PNG)

# %%
def get_distance(Time_sent,Speed_sent):
    """
    Time_sent (tsent) : The timestamp of a message sent by a vehicle
    Speed_sent (ssent) : Vehicle speed at timestamp tsent 
    """
    return get_delay(Time_sent)*Speed_sent

# %% [markdown]
# #### 2 _  expected position :
# * Case 1: We assume that V0 is the leading vehicle on its lane.
# * Case 2: : Vi is not the leading vehicle (i != 0).

# %% [markdown]
# #### for first case :
# ![7.PNG](attachment:7.PNG)

# %% [markdown]
# #### for second case :
# ![8.PNG](attachment:8.PNG)

# %%
class SignalStates:
    GREEN = 0 
    NUMBER_OF_SEGMENT = 3

# %%
def get_position(angle,length_lane,vehicle_state,State_signal,XPosition_sent,YPosition_sent,Time_sent,Speed_sent,vehicle_length=None,Gap=None,PSpeed_sent=None):
    ExpectedXPositiion = XPosition_sent
    ExpectedYPositiion = YPosition_sent
    # first case
    if vehicle_state = 0 :
        if State_signal == 1 : # State_signal is 0 = Green
            if angle == 0 :
                ExpectedXPositiion = XPosition_sent + get_distance(Time_sent,Speed_sent)
            elif angle == 180:
                ExpectedXPositiion = XPosition_sent - get_distance(Time_sent,Speed_sent)
            elif angle == 90:
                ExpectedYPositiion = YPosition_sent + get_distance(Time_sent,Speed_sent)
            elif angle == 270:
                ExpectedYPositiion = YPosition_sent - get_distance(Time_sent,Speed_sent)
        else :
            if angle == 0 :
                ExpectedXPositiion = max(0,XPosition_sent-get_distance(Time_sent,Speed_sent))
            elif angle == 180:
                ExpectedXPositiion = max(0,XPosition_sent-get_distance(Time_sent,Speed_sent))
            elif angle == 90:
                ExpectedYPositiion = max(0,YPosition_sent-get_distance(Time_sent,Speed_sent))
            elif angle == 270:
                ExpectedYPositiion = max(0,YPosition_sent-get_distance(Time_sent,Speed_sent)) 
        
        if ExpectedXPositiion<0 and State_signal==0 and ExpectedXPositiion!=XPosition_sent:
            ExpectedXPositiion = length_lane + abs(ExpectedXPositiion)
        elif ExpectedYPositiion<0 and State_signal==0 and ExpectedYPositiion!=YPosition_sent:
            ExpectedYPositiion = length_lane + abs(ExpectedYPositiion) 
        return ExpectedXPositiion , ExpectedYPositiion
        
    # second case 
    if angle == 0 :
        ExpectedXPositiion = max(XPosition_sent-get_distance(Time_sent,Speed_sent),get_distance(Time_sent,PSpeed_sent)+vehicle_length,Gap)
    elif angle == 180:
        ExpectedXPositiion = max(XPosition_sent-get_distance(Time_sent,Speed_sent),get_distance(Time_sent,PSpeed_sent)+vehicle_length,Gap)
    elif angle == 90:
        ExpectedYPositiion = max(YPosition_sent-get_distance(Time_sent,Speed_sent),get_distance(Time_sent,PSpeed_sent)+vehicle_length,Gap)
    elif angle == 270:
        ExpectedYPositiion = max(YPosition_sent-get_distance(Time_sent,Speed_sent),get_distance(Time_sent,PSpeed_sent)+vehicle_length,Gap)
    return ExpectedXPositiion , ExpectedYPositiion

# %% [markdown]
# # prepare state

# %%
# def lane_segmentation(num_car):
#     number_of_car_accommodate_segment = num_car/SignalStates.NUMBER_OF_SEGMENT
#     t = round((number_of_car_accommodate_segment - floor(number_of_car_accommodate_segment))*SignalStates.NUMBER_OF_SEGMENT)
#     number_of_car_accommodate_segment = floor(number_of_car_accommodate_segment)
#     num_cars_in_segment = []
#     for i in range(SignalStates.NUMBER_OF_SEGMENT):
#         r=0
#         if i==0 and t>0:
#             r=t
#         tepm=number_of_car_accommodate_segment+r
#         if num_car>tepm:
#             num_cars_in_segment.append(num_car-(num_car-tepm))
#         elif num_car>=0 and num_car<=tepm:
#             num_cars_in_segment.append(num_car)
#         else:
#             num_cars_in_segment.append(0)
#         num_car = num_car-tepm
#     return num_cars_in_segment

# %%
def lane_segmentation(length_lane,x_start_lane,y_start_lane,x_end_lane,y_end_lane,x_pos_vehicals,y_pos_vehicals,angel):
    length_seg = length_lane/SignalStates.NUMBER_OF_SEGMENT
    x_start_segments = []
    y_start_segments = []
    x_end_segments = []
    y_end_segments = []
    for i in range(SignalStates.NUMBER_OF_SEGMENT):
        if angle == 0 or angle == 180:
            x_start = x_start_lane
            x_end = x_start_lane+length_seg
            x_start_segments.append(x_start)
            y_start_segments.append(y_start_lane)
            x_end_segments.append(x_end)
            y_end_segments.append(y_end_lane)
            x_start_lane = x_end
        elif angel==270 or angel==90:
            y_start = y_start_lane
            y_end = y_start_lane+length_seg
            x_start_segments.append(x_start)
            y_start_segments.append(y_start_lane)
            x_end_segments.append(x_end)
            y_end_segments.append(y_end_lane)
            y_start_lane = y_end
    return x_start_segments,y_start_segments,x_end_segments,y_end_segments

# %%
def vehicle_distribution_to_segments(x_pos_vehicals,y_pos_vehicals,length_lane,x_start_lane,y_start_lane,x_end_lane,y_end_lane,angel):
    x_start_segments,y_start_segments,x_end_segments,y_end_segments = lane_segmentation(length_lane,x_start_lane,y_start_lane,x_end_lane,y_end_lane,angel)
    num_vehicals_in_segment = np.zeros(len(x_start_segments))
    for i,x_pos_vehical in enumerate(x_pos_vehicals):
        if angle == 0 or angle == 180:
            for j,x_start_segment in enumerate(x_start_segments):
                if x_start_segments[j]>=x_pos_vehicals[i] and x_pos_vehicals[i]<x_end_segments[j]:
                    num_vehicals_in_segment[j]+=1
                    break
        elif angel==270 or angel==90:
            for j,y_start_segment in enumerate(y_start_segments):
                if y_start_segments[j]>=y_pos_vehicals[i] and y_pos_vehicals[i]<y_end_segments[j]:
                    num_vehicals_in_segment[j]+=1
                    break
    return num_vehicals_in_segment

# %%
from statistics import mean
def get_state(agent_id=0):
    ts = sorted(list(set(df['timestamp'].tolist())))
    for t in ts:
        if t==0:
            continue
        print("========================","for time",t,"========================")
        t_df = df[df['timestamp']==t]
        inter = t_df[t_df['intersction_id']==agent_id]
        lanes_ids = list(set(inter['lane_id'].tolist()))
        print(len(lanes_ids),lanes_ids)
        S_lane = []
        signal_state = []
        m_speed = []
        m_acceleration = []
        m_volume = []
        for i in lanes_ids:
#             _speed = []
#             _acceleration = []
#             _volume = []
            lane = inter[inter['lane_id']==i]
            S_lane = lane_segmentation(lane['number_of_vehical_on_lane'].tolist()[0])
            print(S_lane)
            l = 0 
            for s,segment in enumerate(S_lane):
                segment = int(segment)
                if segment!=0:
                    ave_speed = mean(lane['vehicle_speed'][l:segment+l].tolist())
                    ave_acc = mean(lane['vehicle_acceleration'][l:segment+l].tolist())
                else:
                    ave_speed  = 0
                    ave_acc = 0
                vehicle_volumes = segment
                m_volume.append(vehicle_volumes)
                m_speed.append(ave_speed)
                m_acceleration.append(ave_acc)
                l = segment
            m_volume.append(lane['num_veh_neighbor_lane_2'].tolist()[0])
            m_speed.append(lane['avg_speed_veh_neighbor_lane'].tolist()[0])
            m_acceleration.append(lane['avg_acceleration_veh_neighbor_lane'].tolist()[0])  
            signal_state.append(lane['traffic_light_state'].tolist()[0])
        x = np.array(m_volume+m_speed+m_acceleration+signal_state)
        print(x)
        print(x.shape)
    #     m_speed = np.array(m_speed)
    #     m_acceleration = np.array(m_acceleration)
    #     m_volume = np.array(m_volume)
    #     signal_state = np.array(signal_state)

    #     print("m_speed : \n",m_speed)#.reshape(lane.shape[0],-1))
    #     print("m_acceleration : \n",m_acceleration)#.reshape(lane.shape[0],-1))
    #     print("m_volume : \n",m_volume)#.reshape(lane.shape[0],-1))
    #     print("signal_state : \n",signal_state)
    #     print("After concatenat :")
#     return x , x.shape

# %%
for j,i in enumerate(list(set(df['intersction_id'].tolist()))):
    print("___________________________________",str(j)+"- "+str(i),"______________________________________")
    state ,shape = get_state(i)
#     print(state)
#     print(shape)
# Out:
# ___________________________________ 0- 0 ______________________________________
# ======================== for time 5 ========================
# 3 ['-E14_0', '-E22_0', '-E18_0']
# [1, 0, 0]
# [1, 0, 0]
# [2, 0, 0]
# [ 1.          0.          0.          1.          1.          0.
#   0.          2.          2.          0.          0.          0.
#  27.42        0.          0.          5.34112668 30.31        0.
#   0.          6.85671492 17.38        0.          0.          5.19800612
#   1.96112124  0.          0.          1.54065513  2.38341458  0.
#   0.          1.86037911  1.55150492  0.          0.          2.10163006
#   0.          0.          1.        ]
# (39,)
# ======================== for time 10 ========================
# 3 ['-E14_0', '-E22_0', '-E18_0']
# [1, 0, 0]
# [1, 0, 0]
# [2, 0, 0]
# [ 1.          0.          0.          1.          1.          0.
#   0.          3.          2.          0.          0.          0.
# ...

# %%
df.head()
# Out:
#    timestamp                               vehicle_id  X_vehicle_position  \
# 0          0                                        0          483.170000
# 1          5                                        0          461.883712
# 2          5  Veh0d9c3b12-0ca4-46ae-8a11-804f0b05a35f          401.600000
# 3          5  Veh12976018-5e54-44b9-a618-da6fd42a4280          398.400000
# 4          5  Veh188bf066-b9c8-42d4-ba41-7c09e306ac26          201.600000
#
#    Y_vehicle_position  vehicle_speed  vehicle_acceleration  \
# 0            1.600000           0.00              0.000000
# 1            1.600000          23.48              0.788203
# 2          -81.199049           7.86              2.098379
# 3           61.421370          29.47              1.712451
# 4         -262.693138          31.36              2.517969
#
#    traffic_light_state                         front_vehicle_id lane_id  \
# 0                    0                                       -1  -E16_0
# ...

# %%
class RLAlgorithm(ABC):
    # , env: Environment
    def __init__(self, total_episodes=10000, lr=0.5, gamma=0.9, epsilon=0.9, decay=0.99, min_epsilon=0.1):
#         self.env = env
        self.total_episodes = total_episodes
        self.lr = lr
        self.gamma = gamma
        self.epsilon = epsilon
        self.decay = decay
        self.min_epsilon = min_epsilon
        self.algorithm_name = ""

    @abstractmethod
    def fit(self, *args, **kwargs):
        pass

    @abstractmethod
    def policy(self, *args, **kwargs):
        pass

    @abstractmethod
    def value_function(self, state: int, *args, **kwargs):
        pass

    @abstractmethod
    def save(self, path=".", file_name=None):
        pass

    @abstractmethod
    def load(self, path):
        pass

    def plot_reward(self, step=5, color="blue"):
        plt.figure(figsize=(6, 4))
        plt.title(self.algorithm_name)
        # Plot The Pair Of (Reward, Episodes) Each Step
        plt.plot([i for i, x in enumerate(self.rewards) if i % step == 0],
                 [x for i, x in enumerate(self.rewards) if i % step == 0], color=color)
        plt.xlabel('Episodes')
        plt.ylabel('Total Reward per Epidode')

# %%
class DQN(RLAlgorithm):
    # , env
    def __init__(self, epochs=100, max_steps=99,neurons_num:list = [128,32], lr=0.001, gamma=0.8, epsilon=0.5, decay=0.999, min_epsilon=0.1, batch_size=32,max_len_queue=1000):
        # env,
        super().__init__(epochs, lr, gamma, epsilon, decay, min_epsilon)
        self.algorithm_name = "DQN"
        self.max_steps = max_steps
        self.rewards = []
        self.EPOCHS = epochs
        self.batch_size = batch_size
        self.memory = deque(maxlen=max_len_queue)
        self.neurons_num_list = neurons_num
        self.model = self.create_model()
        self.model.summary()

    def create_model(self):
        model = Sequential()
        model.add(Input(shape))
        for n in self.neurons_num_list:
            model.add(Dense(n, activation=LeakyReLU(alpha=0.01)))
        model.add(Dense(2,activation='linear', name="Actions"))
        model.compile(loss='mse', optimizer=Adam(learning_rate=0.001, decay=0.01))
        return model
    
    def remember(self, state_idx, action_idx, reward, next_state_idx, done):
        self.memory.append(
            (state_idx, action_idx, reward, next_state_idx, done))

    def replay(self):
        x_batch, y_batch = [], []
        mini_batch = random.sample(
            self.memory, min(len(self.memory), self.batch_size))
        for state_idx, action_idx, reward, next_state_idx, done in mini_batch:
            y_target = self.pred(state_idx)

            y_target[0][action_idx] = reward if done else reward + \
                self.gamma * self.Q_next(next_state_idx)
            x_batch.append(self.state_as_one_hot_encoding(state_idx).squeeze())
            y_batch.append(y_target[0])
        self.model.fit(np.array(x_batch),np.array(y_batch),
                    batch_size=len(x_batch), verbose=0)
        
        self.epsilon = max(self.epsilon * self.decay, self.min_epsilon)

    def Q_next(self, state):
        return np.max(self.pred(state)[0])

    def fit(self, *args, **kwargs):
        self.total_iters = 0
        total_reward = 0
        for e in tqdm(range(self.EPOCHS)):
            state_idx = self.env.reset()
            done = self.env.is_agent_done()
            for step in range(self.max_steps):
                action_idx = self.policy(state_idx)
                self.env.agent.pos = self.env.next_state(
                    self.env.agent.actions[action_idx])
                new_state_idx = self.env.get_state_index()
                reward = self.env.reward()
                done = self.env.is_agent_done()

                self.remember(state_idx, action_idx,
                              reward, new_state_idx, done)
                state_idx = new_state_idx
                
                total_reward += reward
                self.total_iters += 1
                if done:
                    break

            self.rewards.append(total_reward)
            if len(self.memory) > self.batch_size:
                self.replay()

    def policy(self, state_idx, *args, **kwargs):
        rand = np.random.uniform(0, 1)
        if rand > self.epsilon:
            return self.value_function(state_idx)
        else:
            return np.random.randint(0, self.env.agent.n_actions)

    def state_as_one_hot_encoding(self, idx):
        arr = np.zeros((1, self.env.size))
        arr[0, idx] = 1
        return arr

    def pred(self, state):
        return self.model.predict(self.state_as_one_hot_encoding(state), verbose=0)

    def value_function(self, state: int, *args, **kwargs):
        return np.argmax(self.pred(state))

    def save(self, path=".",file_name=None, *args):
        if os.path.isdir(path):
            if not path.endswith("rl_models"):
                models_path = os.path.join(path, "rl_models")
                if not os.path.isdir(models_path):
                    os.mkdir(models_path)
            else:
                models_path = path
            if file_name:
                self.model.save_weights(os.path.join(models_path,file_name),*args)
            else:
                self.model.save_weights(os.path.join(models_path,"DQN"),*args)
        self.model.save_weights(path,*args)
    
    
    def save_model(self,path=".", file_name=None, *args):
        if os.path.isdir(path):
            if not path.endswith("rl_models"):
                models_path = os.path.join(path,"rl_models")
                if not os.path.isdir(models_path):
                    os.mkdir(models_path)
            else:
                models_path = path
            if file_name:
                __sdm(self.model, os.path.join(models_path,file_name),*args)
            else:
                __sdm(self.model, os.path.join(models_path,"DQN.h5"),*args)
        __sdm(self.model, path, *args)
    
    def load(self, path, *args):
        self.model.load_weights(path,*args)
    
    def load_model(self, path, *args):
        self.model = __ldm(path, *args)

# %%
# import the time module
import time

# get the current time in seconds since the epoch
seconds = time.time()

print("Seconds since epoch =", seconds)

# Output: Seconds since epoch = 1672214933.6804628
# Out:
# Seconds since epoch = 1674981512.306731

# %%
# import the time module
import time

# get the current time in seconds since the epoch
seconds = time.time()

print("Seconds since epoch =", seconds)

# Output: Seconds since epoch = 1672214933.6804628
# Out:
# Seconds since epoch = 1674981512.7315536

# %%
matric3 = [2,4,5,[4,4,5,2],[1,1],5]
matric3 = np.concatenate(matric3, axis=None)
matric3
# Out:
# array([2, 4, 5, 4, 4, 5, 2, 1, 1, 5])

# %%
d = {"0":12,"1":23,"3":34}

# %%
d['1'] = 1222

# %%
d
# Out:
# {'0': 12, '1': 1222, '3': 34}

# %%
np.zeros(2)
# Out:
# array([0., 0.])
